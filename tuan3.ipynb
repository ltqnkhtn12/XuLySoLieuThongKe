# %% [markdown]
# # TUẦN 3: CÁCH BIỂU DIỄN SỐ LIỆU SỐ, HISTOGRSM VÀ HÀM MẬT ĐỘ
#
# - Dạng 1: Dãy số liệu: 170,175,...
#
# - Dạng 2: Bảng tuần suất
#
# - Dạng 3: Bảng tuần suất dạng khoảng
#
# => Dạng 1 cho nhiều thông tin nhất
#
# # LAB 7: VẼ HISTOGRAM
#
# INPUT:
# - DÃY SỐ LIỆU
# - PHƯƠNG PHÁP TÍNH BIN TỐI ƯU
#
# THUẬT TOÁN:
# - DÃY SỐ LIỆU => BẢNG TẦN SUẤT DẠNG KHOẢNG
# - TÍNH CHIỀU RỘNG BIN THEO CÔNG THỨC
# - SỬ DỤNG HÀM VẼ MẬT ĐỘ ĐỒ THỊ BAR + KẾT QỦA 2 VẼ HISTOGRAM
#
# OUTPUT:
# - CÁC LOẠI HISTOGRAM TƯƠNG ỨNG VỚI CÁC PHÂN PHỐI TÍNH TOÁN
#
# TEST:
# - PHÁT SINH SỐ NGẪU NHIÊN CÓ CÁC: PHƯƠNG SAI, PHÂN PHỐI CHUẨN, ĐỀU, CHI BÌNH PHƯƠNG, CAUCHY, FISHER
# - 100,1000,10000,100000

# %%
# import các thư viện
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#plt.rcParams.update({'figure.figsize':(7,3), 'figure.dpi':120})

# %% [markdown]
# # Tính bằng Scott’s Rule

# %% [markdown]
# -thay sigma bằng độ lệch chuẩn mẫu

# %%
def choose_bin_size_scott_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Scott
    n = len(data)
    std_dev = np.std(data)
    bin_width = (3.49 * std_dev) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))

    # Tạo các biên của các bins
    bin_boundaries = np.arange(min_value, max_value + bin_width, bin_width).tolist()

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 10000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.randn(size)

# Chọn kích thước của các bins theo Quy tắc Scott
bin_boundaries = choose_bin_size_scott_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.subplot(1,5,1)
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chuẩn với Quy tắc Scott')
plt.grid(True)
plt.show()
    
def choose_bin_size_scott_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Scott
    n = len(data)
    std_dev = np.std(data)
    bin_width = (3.49 * std_dev) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))

    # Tạo các biên của các bins
    bin_boundaries = np.arange(min_value, max_value + bin_width, bin_width).tolist()

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 10000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.uniform(-5,5,size)

# Chọn kích thước của các bins theo Quy tắc Scott
bin_boundaries = choose_bin_size_scott_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.subplot(1,5,2)
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối đều với Quy tắc Scott')
plt.grid(True)
plt.show()

def choose_bin_size_scott_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Scott
    n = len(data)
    std_dev = np.std(data)
    bin_width = (3.49 * std_dev) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))

    # Tạo các biên của các bins
    bin_boundaries = np.arange(min_value, max_value + bin_width, bin_width).tolist()

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.chisquare(5,10000)

# Chọn kích thước của các bins theo Quy tắc Scott
bin_boundaries = choose_bin_size_scott_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.subplot(1,5,3)
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chi bình phương với Quy tắc Scott')
plt.grid(True)
plt.show()

def choose_bin_size_scott_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Scott
    n = len(data)
    std_dev = np.std(data)
    bin_width = (3.49 * std_dev) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))

    # Tạo các biên của các bins
    bin_boundaries = np.arange(min_value, max_value + bin_width, bin_width).tolist()

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.standard_cauchy(size)
# Chọn kích thước của các bins theo Quy tắc Scott
bin_boundaries = choose_bin_size_scott_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.subplot(1,5,4)
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối cauchy với Quy tắc Scott')
plt.grid(True)
plt.show()

def choose_bin_size_scott_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Scott
    n = len(data)
    std_dev = np.std(data)
    bin_width = (3.49 * std_dev) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))

    # Tạo các biên của các bins
    bin_boundaries = np.arange(min_value, max_value + bin_width, bin_width).tolist()

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 10000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.f(5,10,size)

# Chọn kích thước của các bins theo Quy tắc Scott
bin_boundaries = choose_bin_size_scott_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.subplot(1,5,5)
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối fisher với Quy tắc Scott')
plt.grid(True)
plt.show()

# %% [markdown]
# # Tính bằng Doane’s Rule

# %%
def choose_bin_size_freedman_diaconis_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Freedman-Diaconis
    n = len(data)
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    bin_width = (2 * iqr) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))

    # Tạo các biên của các bins
    bin_boundaries = np.arange(min_value, max_value + bin_width, bin_width).tolist()

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 10000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.randn(size)

# Chọn kích thước của các bins theo Quy tắc Doane’s Rule
bin_boundaries = choose_bin_size_freedman_diaconis_rule(data)
# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.subplot(1,1,1)
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chuẩn với Quy tắc Doane’s Rule')
plt.grid(True)
plt.show()

def choose_bin_size_freedman_diaconis_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Freedman-Diaconis
    n = len(data)
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    bin_width = (2 * iqr) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))

    # Tạo các biên của các bins
    bin_boundaries = np.arange(min_value, max_value + bin_width, bin_width).tolist()

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 10000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.uniform(-5,5,size)

# Chọn kích thước của các bins theo Quy tắc Scott
bin_boundaries = choose_bin_size_freedman_diaconis_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.subplot(1,2,1)
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chuẩn với Quy tắc Doane’s Rule')
plt.grid(True)
plt.show()

def choose_bin_size_freedman_diaconis_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Freedman-Diaconis
    n = len(data)
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    bin_width = (2 * iqr) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))

    # Tạo các biên của các bins
    bin_boundaries = np.arange(min_value, max_value + bin_width, bin_width).tolist()

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 10000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.uniform(-5,5,size)

# Chọn kích thước của các bins theo Quy tắc Scott
bin_boundaries = choose_bin_size_freedman_diaconis_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.subplot(1,5,1)
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối đều với Quy tắc Doane’s Rule')
plt.grid(True)
plt.show()
    
def choose_bin_size_freedman_diaconis_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Freedman-Diaconis
    n = len(data)
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    bin_width = (2 * iqr) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))

    # Tạo các biên của các bins
    bin_boundaries = np.arange(min_value, max_value + bin_width, bin_width).tolist()

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 10000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.f(5,10,size)

# Chọn kích thước của các bins theo Quy tắc Scott
bin_boundaries = choose_bin_size_freedman_diaconis_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.subplot(1,5,2)
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối đều với Quy tắc Doane’s Rule')
plt.grid(True)
plt.show()

# %% [markdown]
# # Tính bằng Sturge’s Rule

# %%
import math

import math
def choose_bin_size_sturges_rule(data):
    # Tính số lượng bins sử dụng Sturge's Rule
    n = len(data)
    k = 1 + int(math.log2(n))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_width = (max_value - min_value) / k
    bin_boundaries = [min_value + i * bin_width for i in range(k + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.randn(size)

# Chọn kích thước của các bins theo Quy tắc Sturge’s Rule
bin_boundaries = choose_bin_size_sturges_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chuẩn với Quy tắc Sturge’s Rule')
plt.grid(True)
plt.show()

def choose_bin_size_sturges_rule(data):
    # Tính số lượng bins sử dụng Sturge's Rule
    n = len(data)
    k = 1 + int(math.log2(n))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_width = (max_value - min_value) / k
    bin_boundaries = [min_value + i * bin_width for i in range(k + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.uniform(-5,5,size)

# Chọn kích thước của các bins theo Quy tắc Sturge’s Rule
bin_boundaries = choose_bin_size_sturges_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối đều với Quy tắc Sturge’s Rule')
plt.grid(True)
plt.show()


def choose_bin_size_sturges_rule(data):
    # Tính số lượng bins sử dụng Sturge's Rule
    n = len(data)
    k = 1 + int(math.log2(n))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_width = (max_value - min_value) / k
    bin_boundaries = [min_value + i * bin_width for i in range(k + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.chisquare(5,size)

# Chọn kích thước của các bins theo Quy tắc Sturge’s Rule
bin_boundaries = choose_bin_size_sturges_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chi bình phương với Quy tắc Sturge’s Rule')
plt.grid(True)
plt.show()

def choose_bin_size_sturges_rule(data):
    # Tính số lượng bins sử dụng Sturge's Rule
    n = len(data)
    k = 1 + int(math.log2(n))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_width = (max_value - min_value) / k
    bin_boundaries = [min_value + i * bin_width for i in range(k + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 1000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.standard_cauchy(size)

# Chọn kích thước của các bins theo Quy tắc Sturge’s Rule
bin_boundaries = choose_bin_size_sturges_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối cauchy với Quy tắc Sturge’s Rule')
plt.grid(True)
plt.show()

def choose_bin_size_sturges_rule(data):
    # Tính số lượng bins sử dụng Sturge's Rule
    n = len(data)
    k = 1 + int(math.log2(n))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_width = (max_value - min_value) / k
    bin_boundaries = [min_value + i * bin_width for i in range(k + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 1000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.f(5,10,size)

# Chọn kích thước của các bins theo Quy tắc Sturge’s Rule
bin_boundaries = choose_bin_size_sturges_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối fisher với Quy tắc Sturge’s Rule')
plt.grid(True)
plt.show()

# %% [markdown]
# # Tính bằng  Rice’s Rule

# %%
def choose_bin_size_rice_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Rice's Rule
    n = len(data)
    k = int(2 * np.sqrt(n))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_width = (max_value - min_value) / k
    bin_boundaries = [min_value + i * bin_width for i in range(k + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.randn(size)

# Chọn kích thước của các bins theo Quy tắc Rice’s Rule
bin_boundaries = choose_bin_size_rice_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chuẩn với Quy tắc Rice’s Rule')
plt.grid(True)
plt.show()


def choose_bin_size_rice_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Rice's Rule
    n = len(data)
    k = int(2 * np.sqrt(n))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_width = (max_value - min_value) / k
    bin_boundaries = [min_value + i * bin_width for i in range(k + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.uniform(-5,5,size)

# Chọn kích thước của các bins theo Quy tắc Rice’s Rule
bin_boundaries = choose_bin_size_rice_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối đều với Quy tắc Rice’s Rule')
plt.grid(True)
plt.show()


def choose_bin_size_rice_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Rice's Rule
    n = len(data)
    k = int(2 * np.sqrt(n))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_width = (max_value - min_value) / k
    bin_boundaries = [min_value + i * bin_width for i in range(k + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.chisquare(5,size)

# Chọn kích thước của các bins theo Quy tắc Rice’s Rule
bin_boundaries = choose_bin_size_rice_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chi bình phương với Quy tắc Rice’s Rule')
plt.grid(True)
plt.show()


def choose_bin_size_rice_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Rice's Rule
    n = len(data)
    k = int(2 * np.sqrt(n))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_width = (max_value - min_value) / k
    bin_boundaries = [min_value + i * bin_width for i in range(k + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 1000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.standard_cauchy(size)

# Chọn kích thước của các bins theo Quy tắc Rice’s Rule
bin_boundaries = choose_bin_size_rice_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối cauchy với Quy tắc Rice’s Rule')
plt.grid(True)
plt.show()

def choose_bin_size_rice_rule(data):
    # Tính số lượng bins sử dụng Quy tắc Rice's Rule
    n = len(data)
    k = int(2 * np.sqrt(n))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_width = (max_value - min_value) / k
    bin_boundaries = [min_value + i * bin_width for i in range(k + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.f(5,10,size)

# Chọn kích thước của các bins theo Quy tắc Rice’s Rule
bin_boundaries = choose_bin_size_rice_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối fisher với Quy tắc Rice’s Rule')
plt.grid(True)
plt.show()

# %% [markdown]
# # Tính bằng Freedman-Diaconis’s Rule

# %%
def choose_bin_size_freedman_diaconis_rule(data):
    # Tính số lượng bins sử dụng Freedman-Diaconis's Rule
    n = len(data)
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    bin_width = (2 * iqr) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_boundaries = [min_value + i * bin_width for i in range(int((max_value - min_value) / bin_width) + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.randn(size)

# Chọn kích thước của các bins theo Quy tắc Freedman-Diaconis’s Rule
bin_boundaries = choose_bin_size_freedman_diaconis_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chuẩn với Quy tắc Freedman-Diaconis’s Rule')
plt.grid(True)
plt.show()

def choose_bin_size_freedman_diaconis_rule(data):
    # Tính số lượng bins sử dụng Freedman-Diaconis's Rule
    n = len(data)
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    bin_width = (2 * iqr) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_boundaries = [min_value + i * bin_width for i in range(int((max_value - min_value) / bin_width) + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.uniform(-5,5,size)

# Chọn kích thước của các bins theo Quy tắc Freedman-Diaconis’s Rule
bin_boundaries = choose_bin_size_freedman_diaconis_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chuẩn với Quy tắc Freedman-Diaconis’s Rule')
plt.grid(True)
plt.show()

def choose_bin_size_freedman_diaconis_rule(data):
    # Tính số lượng bins sử dụng Freedman-Diaconis's Rule
    n = len(data)
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    bin_width = (2 * iqr) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_boundaries = [min_value + i * bin_width for i in range(int((max_value - min_value) / bin_width) + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.chisquare(5, size)

# Chọn kích thước của các bins theo Quy tắc Rice’s Rule
bin_boundaries = choose_bin_size_freedman_diaconis_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chuẩn với Quy tắc Freedman-Diaconis’s Rule')
plt.grid(True)
plt.show()

def choose_bin_size_freedman_diaconis_rule(data):
    # Tính số lượng bins sử dụng Freedman-Diaconis's Rule
    n = len(data)
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    bin_width = (2 * iqr) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_boundaries = [min_value + i * bin_width for i in range(int((max_value - min_value) / bin_width) + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 1000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.standard_cauchy(size)
# Chọn kích thước của các bins theo Quy tắc Rice’s Rule
bin_boundaries = choose_bin_size_freedman_diaconis_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chuẩn với Quy tắc Freedman-Diaconis’s Rule')
plt.grid(True)
plt.show()

def choose_bin_size_freedman_diaconis_rule(data):
    # Tính số lượng bins sử dụng Freedman-Diaconis's Rule
    n = len(data)
    iqr = np.percentile(data, 75) - np.percentile(data, 25)
    bin_width = (2 * iqr) / (n ** (1/3))
    
    # Tìm giá trị nhỏ nhất và lớn nhất trong dữ liệu
    min_value = int(min(data))
    max_value = int(max(data))
    
    # Tạo các biên của các bins
    bin_boundaries = [min_value + i * bin_width for i in range(int((max_value - min_value) / bin_width) + 1)]

    return bin_boundaries

# Dữ liệu mẫu
# Tham số của phân phối chuẩn
mean = sum(data)/len(data)  # Giá trị trung bình
std_dev = np.std(data)  # Độ lệch chuẩn (standard deviation)
size = 100000  # Số lượng số ngẫu nhiên bạn muốn phát sinh

# Phát sinh số ngẫu nhiên theo phân phối chuẩn
data = np.random.f(5,10,size)
# Chọn kích thước của các bins theo Quy tắc Freedman-Diaconis’s Rule
bin_boundaries = choose_bin_size_freedman_diaconis_rule(data)

# Tạo các bins và tính tần suất xuất hiện của từng bin
hist, _ = np.histogram(data, bins=bin_boundaries, density=True)

# Vẽ biểu đồ cột
plt.bar(bin_boundaries[:-1], hist, width=bin_boundaries[1]-bin_boundaries[0], edgecolor='k')
plt.xlabel('Giá trị')
plt.ylabel('Tần suất')
plt.title('Biểu đồ cột của phân phối chuẩn với Quy tắc Freedman-Diaconis’s Rule')
plt.grid(True)
plt.show()
